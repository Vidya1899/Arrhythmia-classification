# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#    age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 0   75    0     190      80            91           193           371
# 1   56    1     165      64            81           174           401
# 2   54    0     172      95           138           163           386
# 3   55    0     175      94           100           202           380
# 4   75    0     190      80            88           181           360
#
#    t_interval  p_interval  qrs  ...    KU   KV   KY    KZ   LA   LD   LE  \
# 0         174         121  -16  ...  62.9 -0.3  0.0   9.0 -0.9  0.9  2.9
# 1         149          39   25  ...  43.4 -0.5  0.0   8.5  0.0  0.2  2.1
# 2         185         102   96  ...  48.2  0.9  0.0   9.5 -2.4  0.3  3.4
# 3         179         143   28  ...  68.0  0.1  0.0  12.2 -2.2  0.4  2.6
# 4         177         103  -16  ...  48.9 -0.4  0.0  13.1 -3.6 -0.1  3.9
#
#      LF    LG  diagnosis
# 0  23.3  49.4          8
# 1  20.4  38.8          6
# 2  12.3  49.0         10
# ...

# %%
new_df = df.interpolate()
new_df
# Out:
#      age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 0     75    0     190      80            91           193           371
# 1     56    1     165      64            81           174           401
# 2     54    0     172      95           138           163           386
# 3     55    0     175      94           100           202           380
# 4     75    0     190      80            88           181           360
# ..   ...  ...     ...     ...           ...           ...           ...
# 447   53    1     160      70            80           199           382
# 448   37    0     190      85           100           137           361
# 449   36    0     166      68           108           176           365
# 450   32    1     155      55            93           106           386
# 451   78    1     160      70            79           127           364
#
#      t_interval  p_interval  qrs  ...    KU   KV   KY    KZ    LA   LD   LE  \
# ...

# %%
new_df.to_csv (r'new_dataframe.csv', index = False, header=True)

# %%
counter = new_df.isnull().all(axis=1).sum()
print (counter)
# Out:
# 0

# %%
scaler=StandardScaler()

# %%
new_df1=df.replace(to_replace = np.nan, value =12) 
#X_fa = X_np.astype(float)

# %%
newdf2=df.replace(to_replace='?', value=12)

# %%
newdf3=newdf2.astype(float)

# %%
scaler.fit(newdf3)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
